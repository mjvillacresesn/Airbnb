# %%
#US Census API 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

api_key = "9c43c55c9067920bded793b5c4d99ae0aba10281"

c = Census(api_key, year=2012)
api_key
# Out:
# '9c43c55c9067920bded793b5c4d99ae0aba10281'

# %%
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E", "B01002_001E"), {'for': 'county:*'})
census_data
# Out:
# [{'NAME': 'Autauga County, Alabama',
#   'B19013_001E': 53773.0,
#   'B01003_001E': 54590.0,
#   'B01002_001E': 37.0,
#   'B19301_001E': 25253.0,
#   'B17001_002E': 6267.0,
#   'state': '01',
#   'county': '001'},
#  {'NAME': 'Baldwin County, Alabama',
#   'B19013_001E': 50706.0,
#   'B01003_001E': 183226.0,
#   'B01002_001E': 41.2,
#   'B19301_001E': 26769.0,
#   'B17001_002E': 24002.0,
#   'state': '01',
#   'county': '003'},
#  {'NAME': 'Barbour County, Alabama',
#   'B19013_001E': 31889.0,
#   'B01003_001E': 27469.0,
#   'B01002_001E': 38.2,
#   'B19301_001E': 16532.0,
#   'B17001_002E': 6395.0,
#   'state': '01',
#   'county': '005'},
#  {'NAME': 'Bibb County, Alabama',
#   'B19013_001E': 36824.0,
#   'B01003_001E': 22769.0,
#   'B01002_001E': 39.4,
#   'B19301_001E': 17611.0,
#   'B17001_002E': 3594.0,
#   'state': '01',
#   'county': '007'},
#  {'NAME': 'Blount County, Alabama',
#   'B19013_001E': 45192.0,
#   'B01003_001E': 57466.0,
#   'B01002_001E': 39.1,
# ...

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E", "B01002_001E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate"]]

# Visualize
print(len(census_pd))
census_pd.head()
# Out:
# 33120
#   Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601     18544.0        36.4           13495.0             7283.0
# 1   00602     41640.0        38.0           15106.0             8247.0
# 2   00603     54540.0        38.4           15079.0             8913.0
# 3   00606      6593.0        36.8           12098.0             6025.0
# 4   00610     29141.0        38.6           16923.0             7786.0
#
#    Poverty Count  Poverty Rate
# 0        10200.0     55.004314
# 1        23189.0     55.689241
# 2        26776.0     49.094243
# 3         3927.0     59.563173
# 4        14397.0     49.404619

# %%
census_30 = census_pd.groupby('Zipcode').sum()
census_30
# Out:
#          Population  Median Age  Household Income  Per Capita Income  \
# Zipcode
# 00601       18544.0        36.4           13495.0             7283.0
# 00602       41640.0        38.0           15106.0             8247.0
# 00603       54540.0        38.4           15079.0             8913.0
# 00606        6593.0        36.8           12098.0             6025.0
# 00610       29141.0        38.6           16923.0             7786.0
# 00612       69017.0        38.1           18111.0            10203.0
# 00616       10750.0        39.9           16279.0             8613.0
# 00617       24733.0        35.7           15114.0             8358.0
# 00622        5923.0        44.6           12059.0             8168.0
# 00623       44943.0        38.4           16447.0             9197.0
# 00624       26016.0        33.4           15500.0             6929.0
# 00627       35085.0        37.5           17762.0             8368.0
# ...

# %%
zipcode_30 = pd.read_csv("../Final_Trending_Zipcodes.csv")
zipcode_30
# Out:
#     Zip Codes    Borough                   Neighborhood   Mean_2015  \
# 0       11206   Brooklyn      Bushwick and Williamsburg  102.391970
# 1       11221   Brooklyn      Bushwick and Williamsburg   95.713076
# 2       11237   Brooklyn      Bushwick and Williamsburg   91.916442
# 3       11216   Brooklyn               Central Brooklyn  111.900207
# 4       11238   Brooklyn               Central Brooklyn  144.082211
# 5       10027  Manhattan                 Central Harlem  128.709048
# 6       10011  Manhattan            Chelsea and Clinton  242.854346
# 7       10019  Manhattan            Chelsea and Clinton  229.525049
# 8       10036  Manhattan            Chelsea and Clinton  218.437125
# 9       10029  Manhattan                    East Harlem  126.461440
# 10      11226   Brooklyn                       Flatbush   92.680582
# 11      10016  Manhattan  Gramercy Park and Murray Hill  237.572914
# 12      11211   Brooklyn                     Greenpoint  150.991682
# ...

# %%
zips = zipcode_30.groupby('Zip Codes').count()
zips = zips.sort_values('Borough', ascending=False)

zip_list = list(zips.index.values)
zipcodes = zip_list[0:30]
zipcodes
# Out:
# [10002,
#  11201,
#  11237,
#  11233,
#  11226,
#  11225,
#  11222,
#  11221,
#  11217,
#  11216,
#  11215,
#  11211,
#  11206,
#  11205,
#  10036,
#  10003,
#  10031,
#  10029,
#  10027,
#  10025,
#  10024,
#  10023,
#  10019,
#  10016,
#  10014,
#  10012,
#  10011,
#  10009,
#  11238]

# %%
Population = []
Household_Income = []

for zipcode in zipcodes:
    population = census_pd.loc[census_pd['Zipcode']==zipcode]['Population'].count()
    income = census_pd.loc[census_pd['Zipcode']==zipcode]['Household Income'].count()
    Population.append(population)
    Household_Income.append(income)

test_census = pd.DataFrame({
    'Zip Code':zipcodes,
    'Population': Population,
    'Household_Income': Household_Income
})
test_census
# Out:
#     Zip Code  Population  Household_Income
# 0      10002           0                 0
# 1      11201           0                 0
# 2      11237           0                 0
# 3      11233           0                 0
# 4      11226           0                 0
# 5      11225           0                 0
# 6      11222           0                 0
# 7      11221           0                 0
# 8      11217           0                 0
# 9      11216           0                 0
# 10     11215           0                 0
# 11     11211           0                 0
# 12     11206           0                 0
# 13     11205           0                 0
# 14     10036           0                 0
# 15     10003           0                 0
# 16     10031           0                 0
# 17     10029           0                 0
# 18     10027           0                 0
# 19     10025           0                 0
# 20     10024           0                 0
# ...
